# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnu5190/AI-MONITOR/blob/main/Day1(AI).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image1 = cv2.imread('road.bmp', cv2.IMREAD_GRAYSCALE)
image2 = cv2.imread('lenna.png', cv2.IMREAD_GRAYSCALE)
print('Image 1 Shape:', image1.shape)
print('Image 2 Shape:', image2.shape)
# Out:
# Image 1 Shape: (256, 256)
# Image 2 Shape: (256, 256)

# %% [markdown]
# 1. IMAGE ADDITION

# %%
res = cv2.addWeighted(image1, 0.6, image2, 0.4, 0)

fig = plt.figure(figsize=(10,10))
ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)

ax1.imshow(image1, cmap='gray')
ax1.title.set_text('First Image (Weight: 60%)')
ax2.imshow(image2, cmap='gray')
ax2.title.set_text('Second Image (Weight: 40%)')
ax3.imshow(res, cmap='gray')
ax3.title.set_text('Resulting Image after Addition')
plt.show()

# %% [markdown]
# 2. IMAGE SUBSTRACTION

# %%
res = cv2.subtract(image1, image2)

fig = plt.figure(figsize=(10,10))
ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)

ax1.imshow(image1, cmap='gray')
ax1.title.set_text('First Image')
ax2.imshow(image2, cmap='gray')
ax2.title.set_text('Second Image')
ax3.imshow(res, cmap='gray')
ax3.title.set_text('Resulting Image after Subtraction')
plt.show()

# %% [markdown]
# 3. bitwise operation

# %%
image1 = cv2.imread('peppers.png')
image2 = cv2.imread('opencv_logo.png')

# %%
rows, cols, channels = image2.shape
roi = image1[0:rows, 0:cols]

# %%
gray_image = cv2.cvtColor(image2,cv2.COLOR_BGR2GRAY)
ret, mask = cv2.threshold(gray_image, 150, 255, cv2.THRESH_BINARY_INV)
mask_inv = cv2.bitwise_not(mask)
plt.title('Image 2 Mask')
plt.imshow(mask, cmap='gray')
plt.show()

# %%
image1_bg = cv2.bitwise_or(roi, roi, mask = mask_inv)
image2_fg = cv2.bitwise_or(image2, image2, mask = mask)

# %%
dst = cv2.add(image1_bg,image2_fg)
image1_added = image1
image1_added[0:rows, 0:cols ] = dst
image1_added = cv2.cvtColor(image1_added, cv2.COLOR_BGR2RGB) # For matplotlib imshow
plt.title('Logo Added using Bitwise Operations')
plt.imshow(image1_added)
plt.show()

# %% [markdown]
# ---------------------Applying geometric transformation for the image.------

# %%
image = cv2.imread('peppers.png')

# %%
import numpy as np

# %%
translation_matrix = np.float32([[1, 0, 100], [0, 1, 50]])
translated_image = cv2.warpAffine(image, translation_matrix, (image.shape[1], image.shape[0]))

# %%
rotation_matrix = cv2.getRotationMatrix2D((image.shape[1] / 2, image.shape[0] / 2), 45, 1)
rotated_image = cv2.warpAffine(image, rotation_matrix, (image.shape[1], image.shape[0]))

# %%
scaling_factor = 0.5
scaled_image = cv2.resize(image, None, fx=scaling_factor, fy=scaling_factor)

# %%
shear_matrix = np.float32([[1, 0.5, 0], [0.5, 1, 0]])
sheared_image = cv2.warpAffine(image, shear_matrix, (image.shape[1], image.shape[0]))

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow( translated_image)
cv2_imshow( rotated_image)
cv2_imshow( scaled_image)
cv2_imshow( sheared_image)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FBF4660F910>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FBF4660F7F0>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FBF4660F910>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FBF4660C760>

# %% [markdown]
# --------------------Operations to blur and deblur an image.---------------------

# %%
blurred_image = cv2.GaussianBlur(image, (5, 5), 0)

# %%
psf = np.ones((5, 5)) / 25

# %%
cv2_imshow( blurred_image)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FBF467A0460>

# %% [markdown]
# --------------------Edge Detection – explore various techniques----------------------

# %%
image = cv2.imread('lenna.png', 0)

# %%
blurred = cv2.GaussianBlur(image, (5, 5), 0)

# %%
edges = cv2.Canny(blurred, 30, 70)

# %%
cv2_imshow( image)
cv2_imshow( edges)
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7FBF467BEEC0>
# <PIL.Image.Image image mode=L size=256x256 at 0x7FBF466DFBB0>
